# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

tqdm.pandas()

# %%
df_olympics = pd.read_csv('data/olympic_history/athlete_events.csv')
df_noc = pd.read_csv('data/olympic_history/noc_regions.csv')

# %%
df_olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_olympics['Medal'] = df_olympics['Medal'].fillna("")
df_olympics.loc[df_olympics['Medal'] == 'Gold', 'mcount'] = 3
df_olympics.loc[df_olympics['Medal'] == 'Silver', 'mcount'] = 2
df_olympics.loc[df_olympics['Medal'] == 'Bronze', 'mcount'] = 1
df_olympics.loc[df_olympics['Medal'] == '', 'mcount'] = 0

df_olympics['mcount'] = df_olympics['mcount'].astype(int)

df_olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  mcount
# 0       Basketball Men's Basketball             0
# 1      Judo Men's Extra-Lightweight             0
# ...

# %%
# df_olympics = df_olympics.groupby(['NOC', 'Year', 'Event']).agg({'mcount': 'sum'}).reset_index()

# %%
df_olympics = df_olympics.merge(df_noc, on='NOC')

df_olympics.head()
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal  mcount region notes
# 0               Basketball Men's Basketball             0  China   NaN
# 1              Judo Men's Extra-Lightweight             0  China   NaN
# ...

# %%
df_olympics = df_olympics.drop(['notes'], axis = 1)
display(df_olympics)
# Out:
#             ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 0            1           A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1            2            A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2          602       Abudoureheman   M  22.0   182.0    75.0    China  CHN
# 3         1463           Ai Linuer   M  25.0   160.0    62.0    China  CHN
# 4         1464           Ai Yanhan   F  14.0   168.0    54.0    China  CHN
# ...        ...                 ...  ..   ...     ...     ...      ...  ...
# 270762  120575     Mamorallo Tjoka   F  23.0   150.0    56.0  Lesotho  LES
# 270763  120575     Mamorallo Tjoka   F  27.0   150.0    56.0  Lesotho  LES
# 270764  122166  M'apotlaki Ts'elho   F  15.0     NaN     NaN  Lesotho  LES
# 270765  122215          Lefa Tsapi   M  23.0   170.0    63.0  Lesotho  LES
# 270766  122299       Mosolesa Tsie   M  20.0   175.0    75.0  Lesotho  LES
#
#               Games  Year  Season            City       Sport  \
# ...

# %%
# df_olympics.columns = ['NOC', 'Year', 'Event', 'mcount', 'Country']
df_olympics = df_olympics.dropna()
df_olympics.head()
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal  mcount region
# 0               Basketball Men's Basketball             0  China
# 1              Judo Men's Extra-Lightweight             0  China
# ...

# %%
final_dataset = df_olympics.copy()

# %%
from geopy.geocoders import Nominatim
latlng_country = {}

countries = final_dataset['region'].copy().unique()

geolocator = Nominatim(user_agent="data-processing")
for country in countries:
    try:
        loc = geolocator.geocode(country)
        latlng_country[country] = (loc.latitude, loc.longitude)
    except:
        print("unable to geocode " + country)
# Out:
# unable to geocode Individual Olympic Athletes

# %%
def geolocate(row):
    country = row['region']
    try:
        loc = latlng_country[country]
        row['lat'] = loc[0]
        row['long'] = loc[1]
        return row
    except:
        return np.nan

final_dataset = final_dataset.progress_apply(lambda row: geolocate(row), axis=1)
print(final_dataset.shape)
final_dataset = final_dataset.dropna()
print(final_dataset.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 205895/205895 [02:36<00:00, 1314.25it/s]
# (205895, 19)
# (205827, 19)

# %%
display(final_dataset)
# Out:
#               ID                    Name Sex   Age  Height  Weight     Team  \
# 0            1.0               A Dijiang   M  24.0   180.0    80.0    China
# 1            2.0                A Lamusi   M  23.0   170.0    60.0    China
# 2          602.0           Abudoureheman   M  22.0   182.0    75.0    China
# 3         1463.0               Ai Linuer   M  25.0   160.0    62.0    China
# 4         1464.0               Ai Yanhan   F  14.0   168.0    54.0    China
# ...          ...                     ...  ..   ...     ...     ...      ...
# 270760  119487.0  Likeleli Alinah Thamae   F  22.0   170.0    49.0  Lesotho
# 270762  120575.0         Mamorallo Tjoka   F  23.0   150.0    56.0  Lesotho
# 270763  120575.0         Mamorallo Tjoka   F  27.0   150.0    56.0  Lesotho
# 270765  122215.0              Lefa Tsapi   M  23.0   170.0    63.0  Lesotho
# 270766  122299.0           Mosolesa Tsie   M  20.0   175.0    75.0  Lesotho
#
# ...

# %%
final_dataset.to_csv('data/final_data_with_sports.csv')

# %%
tmp = final_dataset.groupby(['NOC', 'Medal']).size().unstack(fill_value=0)
tmp
# Out:
# Medal        Bronze  Gold  Silver
# NOC
# AFG      52       2     0       0
# AHO      51       0     0       0
# ALB      57       0     0       0
# ALG     466       6     5       4
# AND     135       0     0       0
# ..      ...     ...   ...     ...
# YEM      25       0     0       0
# YMD       2       0     0       0
# YUG    1323      83   122     116
# ZAM     127       0     0       1
# ZIM     265       1    17       4
#
# [222 rows x 4 columns]
